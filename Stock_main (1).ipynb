# %% [markdown]
# ## Stock Market Prediction and Forecasting Using stacked LSTM

# %% [markdown]
# ### The steps I am following to complete this project is
# #### 1.Data collection of the stocks -- AAPL
# #### 2.Preprocess the dataset into training and testing
# #### 3.Create a stacked LSTM model
# #### 4.Predict the test data and plot the output
# #### To chek the data [click here](https://finance.yahoo.com/quote/AAPL/history/)

# %%
# Data collection
# Using pandas datareader to get the dataset
import pandas_datareader as pdr

# %%
# From Tiingo I am importing my entire data
# which is a platform for stock market tools
data=pdr.get_data_tiingo('AAPL',api_key="************************************") #use your own api key to get an access

# %%
# now let's have a look into the dataset
data
# Out:
#                                    close      high      low      open  \
# symbol date
# AAPL   2015-07-30 00:00:00+00:00  122.37  122.5699  121.710  122.3200
#        2015-07-31 00:00:00+00:00  121.30  122.6425  120.910  122.6000
#        2015-08-03 00:00:00+00:00  118.44  122.5700  117.520  121.5000
#        2015-08-04 00:00:00+00:00  114.64  117.7000  113.250  117.4200
#        2015-08-05 00:00:00+00:00  115.40  117.4400  112.100  112.9500
# ...                                  ...       ...      ...       ...
#        2020-07-21 00:00:00+00:00  388.00  397.0000  386.970  396.6900
#        2020-07-22 00:00:00+00:00  389.09  391.9000  386.410  386.7700
#        2020-07-23 00:00:00+00:00  371.38  388.3100  368.039  387.9935
#        2020-07-24 00:00:00+00:00  370.46  371.8800  356.580  363.9500
#        2020-07-27 00:00:00+00:00  379.24  379.6200  373.920  374.8400
#
#                                      volume    adjClose     adjHigh  \
# symbol date
# AAPL   2015-07-30 00:00:00+00:00   33628268  112.766819  112.951031
#        2015-07-31 00:00:00+00:00   42884953  111.780789  113.017934
#        2015-08-03 00:00:00+00:00   69975968  109.145232  112.951123
#        2015-08-04 00:00:00+00:00  124138623  105.643443  108.463304
#        2015-08-05 00:00:00+00:00   98384461  106.343801  108.223708
# ...                                     ...         ...         ...
#        2020-07-21 00:00:00+00:00   25627347  388.000000  397.000000
#        2020-07-22 00:00:00+00:00   22250413  389.090000  391.900000
#        2020-07-23 00:00:00+00:00   49251108  371.380000  388.310000
#        2020-07-24 00:00:00+00:00   46359716  370.460000  371.880000
#        2020-07-27 00:00:00+00:00   30303548  379.240000  379.620000
#
#                                       adjLow     adjOpen  adjVolume  divCash  \
# symbol date
# AAPL   2015-07-30 00:00:00+00:00  112.158613  112.720742   33628268      0.0
#        2015-07-31 00:00:00+00:00  111.421394  112.978769   42884953      0.0
#        2015-08-03 00:00:00+00:00  108.297430  111.965093   69975968      0.0
#        2015-08-04 00:00:00+00:00  104.362525  108.205278  124138623      0.0
#        2015-08-05 00:00:00+00:00  103.302773  104.086068   98384461      0.0
# ...                                      ...         ...        ...      ...
#        2020-07-21 00:00:00+00:00  386.970000  396.690000   25627347      0.0
#        2020-07-22 00:00:00+00:00  386.410000  386.770000   22250413      0.0
#        2020-07-23 00:00:00+00:00  368.039000  387.993500   49251108      0.0
#        2020-07-24 00:00:00+00:00  356.580000  363.950000   46359716      0.0
#        2020-07-27 00:00:00+00:00  373.920000  374.840000   30303548      0.0
#
#                                   splitFactor
# symbol date
# AAPL   2015-07-30 00:00:00+00:00          1.0
#        2015-07-31 00:00:00+00:00          1.0
#        2015-08-03 00:00:00+00:00          1.0
#        2015-08-04 00:00:00+00:00          1.0
#        2015-08-05 00:00:00+00:00          1.0
# ...                                       ...
#        2020-07-21 00:00:00+00:00          1.0
#        2020-07-22 00:00:00+00:00          1.0
#        2020-07-23 00:00:00+00:00          1.0
#        2020-07-24 00:00:00+00:00          1.0
#        2020-07-27 00:00:00+00:00          1.0
#
# [1257 rows x 12 columns]

# %%
# changing the format of our dataset 
# converting it into a csv file
data.to_csv('AAPL.csv')

# %%
# importing pandas here to structurized out dataset into a pandas dataframe
# for further preprocessing steps
import pandas as pd

# %%
df=pd.read_csv("AAPL.csv")
df
# Out:
#      symbol                       date   close      high      low      open  \
# 0      AAPL  2015-07-30 00:00:00+00:00  122.37  122.5699  121.710  122.3200
# 1      AAPL  2015-07-31 00:00:00+00:00  121.30  122.6425  120.910  122.6000
# 2      AAPL  2015-08-03 00:00:00+00:00  118.44  122.5700  117.520  121.5000
# 3      AAPL  2015-08-04 00:00:00+00:00  114.64  117.7000  113.250  117.4200
# 4      AAPL  2015-08-05 00:00:00+00:00  115.40  117.4400  112.100  112.9500
# ...     ...                        ...     ...       ...      ...       ...
# 1252   AAPL  2020-07-21 00:00:00+00:00  388.00  397.0000  386.970  396.6900
# 1253   AAPL  2020-07-22 00:00:00+00:00  389.09  391.9000  386.410  386.7700
# 1254   AAPL  2020-07-23 00:00:00+00:00  371.38  388.3100  368.039  387.9935
# 1255   AAPL  2020-07-24 00:00:00+00:00  370.46  371.8800  356.580  363.9500
# 1256   AAPL  2020-07-27 00:00:00+00:00  379.24  379.6200  373.920  374.8400
#
#          volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0      33628268  112.766819  112.951031  112.158613  112.720742   33628268
# 1      42884953  111.780789  113.017934  111.421394  112.978769   42884953
# 2      69975968  109.145232  112.951123  108.297430  111.965093   69975968
# 3     124138623  105.643443  108.463304  104.362525  108.205278  124138623
# 4      98384461  106.343801  108.223708  103.302773  104.086068   98384461
# ...         ...         ...         ...         ...         ...        ...
# 1252   25627347  388.000000  397.000000  386.970000  396.690000   25627347
# 1253   22250413  389.090000  391.900000  386.410000  386.770000   22250413
# 1254   49251108  371.380000  388.310000  368.039000  387.993500   49251108
# 1255   46359716  370.460000  371.880000  356.580000  363.950000   46359716
# 1256   30303548  379.240000  379.620000  373.920000  374.840000   30303548
#
#       divCash  splitFactor
# 0         0.0          1.0
# 1         0.0          1.0
# 2         0.0          1.0
# 3         0.0          1.0
# 4         0.0          1.0
# ...       ...          ...
# 1252      0.0          1.0
# 1253      0.0          1.0
# 1254      0.0          1.0
# 1255      0.0          1.0
# 1256      0.0          1.0
#
# [1257 rows x 14 columns]

# %% [markdown]
# ### We can see the change between the previous dataset with other format and our present dataset  with csv format

# %%
## now I am going to do some preprocessing steps to prepare the dataset to feed it into the model

# %%
df.head()
# Out:
#   symbol                       date   close      high     low    open  \
# 0   AAPL  2015-07-30 00:00:00+00:00  122.37  122.5699  121.71  122.32
# 1   AAPL  2015-07-31 00:00:00+00:00  121.30  122.6425  120.91  122.60
# 2   AAPL  2015-08-03 00:00:00+00:00  118.44  122.5700  117.52  121.50
# 3   AAPL  2015-08-04 00:00:00+00:00  114.64  117.7000  113.25  117.42
# 4   AAPL  2015-08-05 00:00:00+00:00  115.40  117.4400  112.10  112.95
#
#       volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0   33628268  112.766819  112.951031  112.158613  112.720742   33628268
# 1   42884953  111.780789  113.017934  111.421394  112.978769   42884953
# 2   69975968  109.145232  112.951123  108.297430  111.965093   69975968
# 3  124138623  105.643443  108.463304  104.362525  108.205278  124138623
# 4   98384461  106.343801  108.223708  103.302773  104.086068   98384461
#
#    divCash  splitFactor
# 0      0.0          1.0
# 1      0.0          1.0
# 2      0.0          1.0
# 3      0.0          1.0
# 4      0.0          1.0

# %%
df.tail()
# Out:
#      symbol                       date   close    high      low      open  \
# 1252   AAPL  2020-07-21 00:00:00+00:00  388.00  397.00  386.970  396.6900
# 1253   AAPL  2020-07-22 00:00:00+00:00  389.09  391.90  386.410  386.7700
# 1254   AAPL  2020-07-23 00:00:00+00:00  371.38  388.31  368.039  387.9935
# 1255   AAPL  2020-07-24 00:00:00+00:00  370.46  371.88  356.580  363.9500
# 1256   AAPL  2020-07-27 00:00:00+00:00  379.24  379.62  373.920  374.8400
#
#         volume  adjClose  adjHigh   adjLow   adjOpen  adjVolume  divCash  \
# 1252  25627347    388.00   397.00  386.970  396.6900   25627347      0.0
# 1253  22250413    389.09   391.90  386.410  386.7700   22250413      0.0
# 1254  49251108    371.38   388.31  368.039  387.9935   49251108      0.0
# 1255  46359716    370.46   371.88  356.580  363.9500   46359716      0.0
# 1256  30303548    379.24   379.62  373.920  374.8400   30303548      0.0
#
#       splitFactor
# 1252          1.0
# 1253          1.0
# 1254          1.0
# 1255          1.0
# 1256          1.0

# %%
# now I am doing he stock prediction for the "close" but it can be done by other attributes as well 
df1=df.reset_index()['close'] # extracted all the information of the perticular "close" column for the further uses
df1[1200:]
# Out:
# 1200    300.63
# 1201    303.74
# 1202    310.13
# 1203    315.01
# 1204    311.41
# 1205    307.65
# 1206    309.54
# 1207    307.71
# 1208    314.96
# 1209    313.14
# 1210    319.23
# 1211    316.85
# 1212    318.89
# 1213    316.73
# 1214    318.11
# 1215    318.25
# 1216    317.94
# 1217    321.85
# 1218    323.34
# 1219    325.12
# 1220    322.32
# 1221    331.50
# 1222    333.46
# 1223    343.99
# 1224    352.84
# 1225    335.90
# 1226    338.80
# 1227    342.99
# 1228    352.08
# 1229    351.59
# 1230    351.73
# 1231    349.72
# 1232    358.87
# 1233    366.53
# 1234    360.06
# 1235    364.84
# 1236    353.63
# 1237    361.78
# 1238    364.80
# 1239    364.11
# 1240    364.11
# 1241    373.85
# 1242    372.69
# 1243    381.37
# 1244    383.01
# 1245    383.68
# 1246    381.91
# 1247    388.23
# 1248    390.90
# 1249    386.09
# 1250    385.31
# 1251    393.43
# 1252    388.00
# 1253    389.09
# 1254    371.38
# 1255    370.46
# 1256    379.24
# Name: close, dtype: float64

# %%
df1.shape
# Out:
# (1257,)

# %%
# now let's check the ups and downs upto 2020 in stock prices of APPLE
# importing matplotlib library for visualization
import matplotlib.pyplot as plt

# %%
plt.title("Stock Price Records")
plt.plot(df1,"r-") # it's showing the ups and downs of the stock price and 
## we can see the maximize stock price is between 350 to 400 for this year till now

# %%
# LSTM are very sensitive about scaling the data.
# let's scale our data first to use MinMax Scaler

# %%
import numpy as np

# %%
# The sklearn.preprocessing package provides several common utility functions and transformer classes to change 
#raw feature vector into a representation that is more suitable for the downstream estimators.
from sklearn.preprocessing import MinMaxScaler

# %%
# I am going to scale up the data in the range (0,1)
scale=MinMaxScaler(feature_range=(0,1))
df1=scale.fit_transform(np.array(df1).reshape(-1,1))

# %%
# now we can see the change between previous df1 & current df1
# now df1 got change into an array format 
# so that now I can use this for further calculations
df1 
print(type(df1))
# Out:
# <class 'numpy.ndarray'>

# %%
df1.shape
# Out:
# (1257, 1)

# %% [markdown]
# #### Now it's time to split our data for training and testing .While doing this step I had to take care of the category of my dataset.Here I basically use a real time series stock price dataset where everyday's stock price is dependent upon it's previous days stock prices.So train test will be continuous here .I am using 70% of my dataset as for the training and remaining 30% for the testing.

# %%
training_size=int(len(df1)*0.65)
testing_size=len(df1)-training_size

# %%
training_size,testing_size
# Out:
# (817, 440)

# %%
training_data=df1[0:training_size]
training_data[0:10] #scaled train data to fit it into the model to learn it
# Out:
# array([[0.10567818],
#        [0.10214788],
#        [0.09271174],
#        [0.08017421],
#        [0.08268171],
#        [0.08179089],
#        [0.08307763],
#        [0.0969349 ],
#        [0.07637995],
#        [0.08215382]])

# %%
testing_data=df1[training_size:len(df1)]
testing_data[0:10] #scaled test data for testing the model output
# Out:
# array([[0.42713385],
#        [0.41558613],
#        [0.40219077],
#        [0.40568808],
#        [0.42403247],
#        [0.43511828],
#        [0.38648586],
#        [0.36705269],
#        [0.37424527],
#        [0.39463526]])

# %% [markdown]
# Now I will do some data preprocessing steps

# %%
# now converting the arrays into a proper dataset matrix
def creat_dataset_matrix(dataset,time_step=1):
    X_data,Y_data=[],[]
    for i in range(len(dataset)-time_step-1):
        a=dataset[i:(i+time_step),0]
        X_data.append(a)
        Y_data.append(dataset[i+time_step,0])
    return np.array(X_data),np.array(Y_data)

# %%
#time step = it will take previous stock prices into account 
# no of time step = n means it will have a record of previous n stock prices
time_step=100
X_train,y_train=creat_dataset_matrix(training_data,time_step)
X_test,y_test=creat_dataset_matrix(testing_data,time_step)

# %%
print(X_train)
# Out:
# [[0.10567818 0.10214788 0.09271174 ... 0.06928635 0.06149988 0.0517668 ]
#  [0.10214788 0.09271174 0.08017421 ... 0.06149988 0.0517668  0.05605596]
#  [0.09271174 0.08017421 0.08268171 ... 0.0517668  0.05605596 0.05572602]
#  ...
#  [0.32056485 0.31848626 0.32960507 ... 0.43488733 0.43171995 0.41466231]
#  [0.31848626 0.32960507 0.33485103 ... 0.43171995 0.41466231 0.42551717]
#  [0.32960507 0.33485103 0.33973407 ... 0.41466231 0.42551717 0.4299383 ]]

# %%
print(X_train.shape,y_train.shape)
# Out:
# (716, 100) (716,)

# %%
print(X_test.shape,y_test.shape)
# Out:
# (339, 100) (339,)

# %%
#now all inputs are reshaped for fed these into our LSTM model
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
X_train.shape,X_test.shape
# these are reshaped
# Out:
# ((716, 100, 1), (339, 100, 1))

# %%
# creating our stack LSTM Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the data to the LSTM model

model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Train on 716 samples, validate on 339 samples
# Epoch 1/100
# 716/716 [==============================] - 6s 9ms/sample - loss: 0.0171 - val_loss: 0.0447
# Epoch 2/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 0.0032 - val_loss: 0.0036
# Epoch 3/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 9.0243e-04 - val_loss: 0.0038
# Epoch 4/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 6.4655e-04 - val_loss: 0.0030
# Epoch 5/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 4.3365e-04 - val_loss: 0.0038
# Epoch 6/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.9875e-04 - val_loss: 0.0032
# Epoch 7/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.9381e-04 - val_loss: 0.0031
# Epoch 8/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.8584e-04 - val_loss: 0.0029
# Epoch 9/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.8417e-04 - val_loss: 0.0027
# Epoch 10/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.9052e-04 - val_loss: 0.0032
# Epoch 11/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 4.5171e-04 - val_loss: 0.0031
# Epoch 12/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 4.1724e-04 - val_loss: 0.0037
# Epoch 13/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 4.0076e-04 - val_loss: 0.0034
# Epoch 14/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.6363e-04 - val_loss: 0.0032
# Epoch 15/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.5068e-04 - val_loss: 0.0033
# Epoch 16/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.6457e-04 - val_loss: 0.0029
# Epoch 17/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.4739e-04 - val_loss: 0.0038
# Epoch 18/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.8318e-04 - val_loss: 0.0027
# Epoch 19/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.5557e-04 - val_loss: 0.0023
# Epoch 20/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.3857e-04 - val_loss: 0.0026
# Epoch 21/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.2614e-04 - val_loss: 0.0024
# Epoch 22/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.1715e-04 - val_loss: 0.0025
# Epoch 23/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.2314e-04 - val_loss: 0.0024
# Epoch 24/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.0545e-04 - val_loss: 0.0029
# Epoch 25/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.0999e-04 - val_loss: 0.0023
# Epoch 26/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.9239e-04 - val_loss: 0.0022
# Epoch 27/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.8965e-04 - val_loss: 0.0026
# Epoch 28/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.8489e-04 - val_loss: 0.0025
# Epoch 29/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.0333e-04 - val_loss: 0.0022
# Epoch 30/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.8251e-04 - val_loss: 0.0015
# Epoch 31/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 3.0652e-04 - val_loss: 0.0018
# Epoch 32/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.6950e-04 - val_loss: 0.0015
# Epoch 33/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.9844e-04 - val_loss: 0.0022
# Epoch 34/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.5964e-04 - val_loss: 0.0015
# Epoch 35/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.5774e-04 - val_loss: 0.0017
# Epoch 36/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.6092e-04 - val_loss: 0.0015
# Epoch 37/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.4983e-04 - val_loss: 0.0013
# Epoch 38/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.4617e-04 - val_loss: 0.0013
# Epoch 39/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.5709e-04 - val_loss: 0.0019
# Epoch 40/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.6316e-04 - val_loss: 0.0013
# Epoch 41/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.4784e-04 - val_loss: 0.0024
# Epoch 42/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.5015e-04 - val_loss: 0.0012
# Epoch 43/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.3391e-04 - val_loss: 0.0024
# Epoch 44/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.4733e-04 - val_loss: 0.0012
# Epoch 45/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.4561e-04 - val_loss: 0.0014
# Epoch 46/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.2178e-04 - val_loss: 0.0011
# Epoch 47/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.5700e-04 - val_loss: 0.0015
# Epoch 48/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.2496e-04 - val_loss: 0.0015
# Epoch 49/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.2399e-04 - val_loss: 0.0012
# Epoch 50/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.1908e-04 - val_loss: 0.0011
# Epoch 51/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.1903e-04 - val_loss: 0.0015
# Epoch 52/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.2164e-04 - val_loss: 0.0014
# Epoch 53/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.0295e-04 - val_loss: 0.0018
# Epoch 54/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.2223e-04 - val_loss: 0.0024
# Epoch 55/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.8234e-04 - val_loss: 0.0011
# Epoch 56/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.1763e-04 - val_loss: 0.0014
# Epoch 57/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.9543e-04 - val_loss: 0.0013
# Epoch 58/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.9468e-04 - val_loss: 0.0011
# Epoch 59/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.0207e-04 - val_loss: 0.0012
# Epoch 60/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.9345e-04 - val_loss: 0.0015
# Epoch 61/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.8739e-04 - val_loss: 0.0011
# Epoch 62/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.8791e-04 - val_loss: 0.0013
# Epoch 63/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.7938e-04 - val_loss: 0.0013
# Epoch 64/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.8627e-04 - val_loss: 0.0013
# Epoch 65/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.8064e-04 - val_loss: 0.0011
# Epoch 66/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.7747e-04 - val_loss: 0.0019
# Epoch 67/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.9169e-04 - val_loss: 0.0010
# Epoch 68/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.9814e-04 - val_loss: 0.0018
# Epoch 69/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.7440e-04 - val_loss: 0.0013
# Epoch 70/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.6434e-04 - val_loss: 0.0011
# Epoch 71/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.6605e-04 - val_loss: 0.0017
# Epoch 72/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.6920e-04 - val_loss: 9.5549e-04
# Epoch 73/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.6925e-04 - val_loss: 0.0011
# Epoch 74/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.0377e-04 - val_loss: 0.0018
# Epoch 75/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.1947e-04 - val_loss: 0.0012
# Epoch 76/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 2.3461e-04 - val_loss: 0.0015
# Epoch 77/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.8314e-04 - val_loss: 9.6969e-04
# Epoch 78/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.6454e-04 - val_loss: 0.0014
# Epoch 79/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.5137e-04 - val_loss: 0.0014
# Epoch 80/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.7680e-04 - val_loss: 8.6618e-04
# Epoch 81/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.5098e-04 - val_loss: 9.3274e-04
# Epoch 82/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.4775e-04 - val_loss: 8.3231e-04
# Epoch 83/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.3954e-04 - val_loss: 0.0016
# Epoch 84/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.4616e-04 - val_loss: 8.3705e-04
# Epoch 85/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.3935e-04 - val_loss: 9.4312e-04
# Epoch 86/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.3169e-04 - val_loss: 0.0019
# Epoch 87/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.5523e-04 - val_loss: 8.1975e-04
# Epoch 88/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.3107e-04 - val_loss: 7.8428e-04
# Epoch 89/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.4046e-04 - val_loss: 0.0016
# Epoch 90/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.3528e-04 - val_loss: 9.6069e-04
# Epoch 91/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.3557e-04 - val_loss: 8.2719e-04
# Epoch 92/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.3004e-04 - val_loss: 8.7438e-04
# Epoch 93/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.5445e-04 - val_loss: 0.0011
# Epoch 94/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.2156e-04 - val_loss: 8.9356e-04
# Epoch 95/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.3218e-04 - val_loss: 7.5825e-04
# Epoch 96/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.2924e-04 - val_loss: 0.0010
# Epoch 97/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.1920e-04 - val_loss: 6.9649e-04
# Epoch 98/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.1391e-04 - val_loss: 9.4286e-04
# Epoch 99/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.1132e-04 - val_loss: 7.6804e-04
# Epoch 100/100
# 716/716 [==============================] - 2s 3ms/sample - loss: 1.0975e-04 - val_loss: 7.4871e-04

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict=scale.inverse_transform(train_predict)
test_predict=scale.inverse_transform(test_predict)

# %%
test_predict
# Out:
# array([[0.3252807 ],
#        [0.3293637 ],
#        [0.33000255],
#        [0.32682273],
#        [0.322729  ],
#        [0.31952834],
#        [0.31854048],
#        [0.32013586],
#        [0.3247664 ],
#        [0.33138433],
#        [0.3381362 ],
#        [0.34422064],
#        [0.35046086],
#        [0.35547814],
#        [0.35920691],
#        [0.3604332 ],
#        [0.3596152 ],
#        [0.35798717],
#        [0.35641608],
#        [0.35763752],
#        [0.36127973],
#        [0.3660956 ],
#        [0.37230024],
#        [0.37806547],
#        [0.38105875],
#        [0.3808418 ],
#        [0.37888494],
#        [0.37418926],
#        [0.3745726 ],
#        [0.37846723],
#        [0.38509297],
#        [0.38997334],
#        [0.38872355],
#        [0.3834161 ],
#        [0.37584338],
#        [0.3666665 ],
#        [0.35170275],
#        [0.3373459 ],
#        [0.3285389 ],
#        [0.32518566],
#        [0.3252371 ],
#        [0.32375646],
#        [0.32280356],
#        [0.32064304],
#        [0.31612614],
#        [0.3103484 ],
#        [0.30455798],
#        [0.2994769 ],
#        [0.29626626],
#        [0.29318765],
#        [0.28937748],
#        [0.28886855],
#        [0.29279527],
#        [0.30048898],
#        [0.3117339 ],
#        [0.32453126],
#        [0.33683148],
#        [0.34575558],
#        [0.35019645],
#        [0.34983617],
#        [0.3469895 ],
#        [0.34602094],
#        [0.34676024],
#        [0.34923673],
#        [0.35190505],
#        [0.35382503],
#        [0.3530661 ],
#        [0.35301718],
#        [0.35406256],
#        [0.35467476],
#        [0.35683015],
#        [0.3606261 ],
#        [0.3657805 ],
#        [0.37066853],
#        [0.3717022 ],
#        [0.37032226],
#        [0.36919904],
#        [0.36805344],
#        [0.36800534],
#        [0.36997184],
#        [0.3725417 ],
#        [0.3740852 ],
#        [0.37585014],
#        [0.37581727],
#        [0.3771838 ],
#        [0.38066664],
#        [0.38479042],
#        [0.38724273],
#        [0.3882547 ],
#        [0.38943037],
#        [0.3902065 ],
#        [0.39310706],
#        [0.3942988 ],
#        [0.39091873],
#        [0.37856436],
#        [0.36493906],
#        [0.3557945 ],
#        [0.35474572],
#        [0.35799956],
#        [0.36238426],
#        [0.3712038 ],
#        [0.37797245],
#        [0.38050705],
#        [0.38241246],
#        [0.3864447 ],
#        [0.39136815],
#        [0.39690733],
#        [0.4014285 ],
#        [0.3980443 ],
#        [0.39175272],
#        [0.3843572 ],
#        [0.37893036],
#        [0.3783838 ],
#        [0.38123012],
#        [0.3835317 ],
#        [0.38660342],
#        [0.3923281 ],
#        [0.39888787],
#        [0.4049186 ],
#        [0.41073444],
#        [0.41954666],
#        [0.42849782],
#        [0.43238246],
#        [0.43224353],
#        [0.43037367],
#        [0.42953843],
#        [0.42874664],
#        [0.42595088],
#        [0.42296395],
#        [0.42022485],
#        [0.42055708],
#        [0.42245603],
#        [0.4240967 ],
#        [0.42836952],
#        [0.43422905],
#        [0.43607554],
#        [0.43555424],
#        [0.4380137 ],
#        [0.44255084],
#        [0.44544804],
#        [0.44787046],
#        [0.4516439 ],
#        [0.45966408],
#        [0.4685878 ],
#        [0.47516727],
#        [0.47777754],
#        [0.477885  ],
#        [0.47751337],
#        [0.4800177 ],
#        [0.48372525],
#        [0.48927432],
#        [0.4950329 ],
#        [0.5015075 ],
#        [0.50874615],
#        [0.51083785],
#        [0.5088205 ],
#        [0.5090315 ],
#        [0.5162998 ],
#        [0.52767944],
#        [0.5380397 ],
#        [0.54480666],
#        [0.5492547 ],
#        [0.5520913 ],
#        [0.5549813 ],
#        [0.55728054],
#        [0.5605103 ],
#        [0.5624126 ],
#        [0.5652764 ],
#        [0.56936187],
#        [0.57269716],
#        [0.57247114],
#        [0.5694154 ],
#        [0.56576484],
#        [0.56656307],
#        [0.568782  ],
#        [0.5736343 ],
#        [0.5785274 ],
#        [0.57977164],
#        [0.5749941 ],
#        [0.56976575],
#        [0.56918305],
#        [0.57564527],
#        [0.58174556],
#        [0.5864283 ],
#        [0.5907634 ],
#        [0.59445626],
#        [0.59953916],
#        [0.607724  ],
#        [0.6159423 ],
#        [0.6210974 ],
#        [0.6231067 ],
#        [0.6224912 ],
#        [0.62421715],
#        [0.62748235],
#        [0.63496184],
#        [0.6428934 ],
#        [0.64995664],
#        [0.6562813 ],
#        [0.66580725],
#        [0.6725355 ],
#        [0.6773136 ],
#        [0.67886263],
#        [0.6821501 ],
#        [0.6910618 ],
#        [0.70127845],
#        [0.71420395],
#        [0.72158545],
#        [0.72249013],
#        [0.7232634 ],
#        [0.72733456],
#        [0.7305638 ],
#        [0.73327154],
#        [0.73652256],
#        [0.7387521 ],
#        [0.7324577 ],
#        [0.7309045 ],
#        [0.7389129 ],
#        [0.74931794],
#        [0.7456803 ],
#        [0.73481363],
#        [0.7329683 ],
#        [0.73955005],
#        [0.7512548 ],
#        [0.75744265],
#        [0.7596494 ],
#        [0.75793344],
#        [0.7611452 ],
#        [0.76444644],
#        [0.7664501 ],
#        [0.76228625],
#        [0.76005995],
#        [0.75744253],
#        [0.74945253],
#        [0.72902554],
#        [0.7004626 ],
#        [0.6809525 ],
#        [0.6577352 ],
#        [0.63853616],
#        [0.6477504 ],
#        [0.6633952 ],
#        [0.6863863 ],
#        [0.69877553],
#        [0.6971717 ],
#        [0.67028624],
#        [0.65160817],
#        [0.637113  ],
#        [0.6069048 ],
#        [0.59734523],
#        [0.5773688 ],
#        [0.5620496 ],
#        [0.55009544],
#        [0.5414448 ],
#        [0.52547514],
#        [0.50475764],
#        [0.5022226 ],
#        [0.5119179 ],
#        [0.5341307 ],
#        [0.55029863],
#        [0.56124604],
#        [0.5657969 ],
#        [0.5554671 ],
#        [0.5405503 ],
#        [0.5249824 ],
#        [0.52764964],
#        [0.5396544 ],
#        [0.5572907 ],
#        [0.5744508 ],
#        [0.58999133],
#        [0.6104774 ],
#        [0.62700325],
#        [0.6373686 ],
#        [0.6382391 ],
#        [0.62892276],
#        [0.61025083],
#        [0.59782714],
#        [0.593057  ],
#        [0.60006094],
#        [0.61236423],
#        [0.6204526 ],
#        [0.6305564 ],
#        [0.64458317],
#        [0.6535498 ],
#        [0.65968376],
#        [0.66626567],
#        [0.6738912 ],
#        [0.6823004 ],
#        [0.69363505],
#        [0.70720917],
#        [0.7150776 ],
#        [0.7142199 ],
#        [0.71077496],
#        [0.70643026],
#        [0.70920277],
#        [0.7141975 ],
#        [0.7236846 ],
#        [0.7312175 ],
#        [0.7370777 ],
#        [0.73901933],
#        [0.7397569 ],
#        [0.74030405],
#        [0.74067044],
#        [0.7442672 ],
#        [0.7500257 ],
#        [0.75663894],
#        [0.7594487 ],
#        [0.7669516 ],
#        [0.7767492 ],
#        [0.7931113 ],
#        [0.81500065],
#        [0.81839603],
#        [0.8129856 ],
#        [0.80964845],
#        [0.8168048 ],
#        [0.8266923 ],
#        [0.83446485],
#        [0.8371559 ],
#        [0.8446689 ],
#        [0.85929734],
#        [0.8671417 ],
#        [0.872923  ],
#        [0.8670046 ],
#        [0.8647836 ],
#        [0.86877775],
#        [0.8740029 ],
#        [0.87811923],
#        [0.88902026],
#        [0.89890283],
#        [0.91223484],
#        [0.92427605],
#        [0.9320558 ],
#        [0.9338287 ],
#        [0.93805367],
#        [0.9447233 ],
#        [0.94609445],
#        [0.9441543 ],
#        [0.94919866],
#        [0.9514427 ],
#        [0.9527181 ],
#        [0.9382834 ]], dtype=float32)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict)) # we can see loss is very low
# Out:
# 0.010671127058628221

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(y_test,test_predict))  # now we will visualize how our train and test data fits
# Out:
# 0.02736265013110169

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.title("Train Test Trade Off")
plt.plot(scale.inverse_transform(df1))
plt.plot(trainPredictPlot) #plotting the train data
plt.plot(testPredictPlot) #plotting the test data
plt.show()

# %%
# we can see by visualization that our model is predicting the test data well (green coloured line)
#model is ready to predict further stock prices
